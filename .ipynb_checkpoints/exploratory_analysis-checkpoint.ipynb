# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/synthetic/ctgan_auto_50k.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 df = pd.read_csv('../data/synthetic/ctgan_auto_50k.csv')
#       5
#       6 df.head()
#
# ...

# %%
import os
os.listdir('../data/synthetic')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 os.listdir('../data/synthetic')
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '../data/synthetic'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\komal\\ai-insurance-platform'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/synthetic/ctgan_auto_50k.csv')

df.head()
# Out:
#        policy_id   premium  claim_amount  fraud_flag region insurance_type
# 0  sdv-id-SEgbSE  18327.56      17115.62           0    KPK           auto
# 1  sdv-id-UIvAxk  17097.60       5603.13           1     GB           auto
# 2  sdv-id-AXmXVf   9369.43      25395.88           0  Sindh           auto
# 3  sdv-id-bwhwAP  19866.06       9461.02           0    AJK           auto
# 4  sdv-id-sNzsZV  16590.72       7885.70           0    AJK           auto

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   policy_id       50000 non-null  object
#  1   premium         50000 non-null  float64
#  2   claim_amount    50000 non-null  float64
#  3   fraud_flag      50000 non-null  int64
#  4   region          50000 non-null  object
#  5   insurance_type  50000 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# policy_id         0
# premium           0
# claim_amount      0
# fraud_flag        0
# region            0
# insurance_type    0
# dtype: int64

# %%
df.describe()
# Out:
#              premium   claim_amount    fraud_flag
# count   50000.000000   50000.000000  50000.000000
# mean    22415.566918   11703.605181      0.150780
# std     12324.434958   10172.259463      0.357838
# min      3098.890000     370.520000      0.000000
# 25%     14110.850000    4644.322500      0.000000
# 50%     19648.470000    8320.415000      0.000000
# 75%     27443.785000   16170.037500      0.000000
# max    122345.300000  117808.630000      1.000000

# %%
df['fraud_flag'].value_counts()
# Out:
# fraud_flag
# 0    42461
# 1     7539
# Name: count, dtype: int64

# %%
df['region'].value_counts().plot(kind='bar')

plt.title('Policies by Region')

plt.show()

# %%
df['claim_amount'].hist(bins=30)

plt.title('Claim Amount Distribution')

plt.show()
